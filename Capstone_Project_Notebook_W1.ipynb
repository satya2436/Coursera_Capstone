# %% [markdown]
# ## This Notebook will be used for Coursera Capstone Projects

# %%
# Task 1 - Import the pandas library as pd.
import pandas as pd

# %%
# Task 3 - Import the numpy library as np.
import numpy as np

# %%
# Task 4 - Print the following the statement: Hello Capstone Project Course!
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
